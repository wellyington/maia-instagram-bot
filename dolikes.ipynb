# %% [markdown]
# # MAIA Blocks doengagement() function.
# ## Engagement (likes) automation using selenium
# ## Scrap and store information using selenium + SQLite3
#
# Instagram Engagement Automation + Instagram Post Info Scrap.
#
# #### Make sure you run every cluster
# #### The last cluster will prompt informations for engagement (Username, Password, Hashtag and Limit)
#
# ###### Use DB Browser (SQLite3) to browser the data collected during the performance.
#
# ### IMPORTANT
#
# Make sure you have downloaded the Chrome webdriver compatible to your version of Google Chrome and the database file from the repository.

# %%
import random
import sys
import sqlite3
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException, ElementNotInteractableException, ElementClickInterceptedException, TimeoutException
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from time import sleep
from getpass import getpass
import os
import datetime

# %% [markdown]
# # Shell Settings
#
# Settings the Shell / command line

# %%
clear = lambda: os.system('cls')
title = lambda: os.system('title MAIA: Console')
color = lambda: os.system('color a')
colorOff = lambda: os.system('color ')
exit = lambda: os.system('exit')
clear()
title()
color()
# Out:
# 0

# %% [markdown]
# # SQLite3 Connector
#
# Connecting to the SQLite3 Database

# %%
mydb = sqlite3.connect('_data.db')

# %% [markdown]
# # Timer
#
# Timer function

# %%
def timecount(seconds):
    while seconds:
        min, sec = divmod(seconds, 60)
        count = 'Timer: {:d}min:{:d}sec'.format(min, sec)
        print(count, end='\r')
        sleep(1)
        seconds -= 1

# %% [markdown]
# # Instagram Engagement Function
#
# The magic engagement function

# %%
def doengagement(username, password, hashtag, limit):
    driver = webdriver.Chrome(executable_path=r'./chromedriver.exe')
    driver.set_window_position(800, 0)
    driver.set_window_size(200, 800)
    driver.get("https://www.instagram.com/accounts/login/?source=auth_switcher")
    print("Opening instagram.com")
    timecount(2)
    print("Handling Cookies.")
    driver.find_element_by_xpath("//html/body/div[2]/div/div/div/div[2]/button[1]").click()
    timecount(2)
    userLogin = driver.find_element_by_name('username')
    userHashtag = str(hashtag)
    userLogin.send_keys(username)
    print("Handling Username.")
    passLogin = driver.find_element_by_name('password')
    passLogin.send_keys(password)
    print("Handling Password.")
    submit = driver.find_element_by_tag_name('form')
    submit.submit()
    print("Accessing Instagram.")
    timecount(5) 
    driver.get("https://instagram.com/explore/tags/" + userHashtag)
    print("Opening Hashtag #" + userHashtag + ".")
    print("https://instagram.com/explore/tags/" + userHashtag)
    sleep(10)
    driver.find_element_by_xpath("//a[contains(@href, '/p/')]").click()
    print("Starting Engagement.\n")
    timecount(3)
    print("---------------------------------------------------------")
    engagements = 0
    engLimit = int(limit)
    while engagements != engLimit:
        if engagements < engLimit:
            try:
                try:
                    profile = driver.find_element_by_xpath("//html/body/div/div/div/article/header/div/div/div/span/a").text
                    profile_url = driver.current_url
                    date_time = datetime.datetime.now()
                    driver.find_element_by_xpath('//*[name()="svg"][@aria-label="Like"]').click()
                    
                    NULL_ = None
                    _dateTime = str(date_time.date())
                    _dateTime2 = str(date_time.strftime("%X"))

                    sql_insert = "INSERT INTO instagram_engagement (Id, username, hashtag, date, time, profile, post_url) VALUES (?, ?, ?, ?, ?, ?, ?)"
                    sql_values = (NULL_, username, hashtag, _dateTime, _dateTime2, profile, profile_url)
                    maiacursor = mydb.cursor()
                    maiacursor.execute(sql_insert,sql_values)

                    engDisplay = engagements + 1
                    print("Starting Engagement: " + str(engDisplay) + "/" + limit)
                    timecount(1)
                    print("#########################################################")
                    print("Profile: " + profile)
                    print("URL: " + profile_url)
                    print("Date: " + str(date_time.date()))
                    print("Time: " + str(date_time.strftime("%X")))
                    mydb.commit()
                    print("Engagement Recorded.")
                    print("#########################################################")
                    try:
                        try:
                            driver.find_element_by_xpath("//html/body/div[5]/div[1]/div/div/a[2]").click()
                        except:
                            driver.find_element_by_xpath("//html/body/div[5]/div[1]/div/div/a").click()
                    except ElementClickInterceptedException:
                        print("WARNING: Interaction intercepted by Instagram.")
                        status_label.config(text="WARNING: Interaction intercepted by Instagram.")
                        print("Closing Application, please try again later.")
                        timecount(10)
                        print("Disconnecting Driver")
                        status_label.config(text="Disconnecting Chrome Driver")
                        driver.close()
                        timecount(3)
                        print("Disconnecting Database")
                        status_label.config(text="Disconnecting Database")
                        mydb.close()
                        timecount(3)
                        print("Closing MAIA User Interface")
                        status_label.config(text="Closing MAIA Interface")
                        timecount(5)
                        root.destroy()
                        timecount(3)
                        print("EXECUTING KILL COMMAND")
                        timecount(3)
                        exit()
                        timecount(100)
                    print("Completing Engagement.")
                    maia_rand_int_7 = random.randint(3,7)
                    timecount(maia_rand_int_7)
                    print("Engagement Complete.")
                    print("---------------------------------------------------------")
                    engagements += 1
                except ElementNotInteractableException:
                    try:
                        driver.find_element_by_xpath("//html/body/div[5]/div[1]/div/div/a[2]").click()
                    except:
                        driver.find_element_by_xpath("//html/body/div[5]/div[1]/div/div/a").click()
                    print("Post already liked: Moving to the next.")
                    timecount(3)
                    print("Complete.")
                    print("---------------------------------------------------------")
            except NoSuchElementException:
                try:
                    driver.find_element_by_xpath("//html/body/div[5]/div[1]/div/div/a[2]").click()
                except:
                    driver.find_element_by_xpath("//html/body/div[5]/div[1]/div/div/a").click()
                print("Post already liked: Moving to the next. -- NSElement")
                timecount(3)
                print("Complete.")
                print("---------------------------------------------------------")
    else:
        print("\nEngagement Function Complete.")
        timecount(1)
        print("Disconnecting from MAIA Database")
        mydb.close()
        timecount(1)
        print("Closing Browser.")
        colorOff()
        driver.close()

# %% [markdown]
# # Starting Prompt
#
# Giving paraments for the automation.

# %%
print("#########################################################")
print("#               MAIA Blocks - FBI 1.0.1                 #")
print("#########################################################")
insta_username = input("Username: ")
insta_password = getpass("Password: ")
insta_hashtag = input("Hashtagh: ")
insta_limit = input("Limit: ")

doengagement(insta_username, insta_password, insta_hashtag, insta_limit)
# Out:
# #########################################################
# #               MAIA Blocks - FBI 1.0.1                 #
# #########################################################
# Username: wellyington
# Password: ········
# Hashtagh: ibiza
# Limit: 50
# Opening instagram.com
# Handling Cookies.
# Handling Username.
# Handling Password.
# Accessing Instagram.
# Opening Hashtag #ibiza.
# https://instagram.com/explore/tags/ibiza
# Starting Engagement.
#
# ---------------------------------------------------------
# Starting Engagement: 1/50
# #########################################################
# Profile: melissuu
# URL: https://www.instagram.com/p/CMahQmmhdMn/
# Date: 2021-03-15
# Time: 13:51:16
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 2/50
# #########################################################
# Profile: anna.fitnesstrainer
# URL: https://www.instagram.com/p/CMaWq4uMwC-/
# Date: 2021-03-15
# Time: 13:51:27
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 3/50
# #########################################################
# Profile: cansu.dxmir
# URL: https://www.instagram.com/p/CMaV9HpL9Sn/
# Date: 2021-03-15
# Time: 13:51:38
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 4/50
# #########################################################
# Profile: carolinna.br
# URL: https://www.instagram.com/p/CMaV9zpnXa4/
# Date: 2021-03-15
# Time: 13:51:48
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 5/50
# #########################################################
# Profile: jonhyibz
# URL: https://www.instagram.com/p/CMaEzWSrns1/
# Date: 2021-03-15
# Time: 13:51:59
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 6/50
# #########################################################
# Profile: jennbaldridge
# URL: https://www.instagram.com/p/CMZwzFiFuOw/
# Date: 2021-03-15
# Time: 13:52:08
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 7/50
# #########################################################
# Profile: vkarof
# URL: https://www.instagram.com/p/CMb43nfA5Fa/
# Date: 2021-03-15
# Time: 13:52:14
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 8/50
# #########################################################
# Profile: impeccablehotels
# URL: https://www.instagram.com/p/CMaCWOLlrIR/
# Date: 2021-03-15
# Time: 13:52:23
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 9/50
# #########################################################
# Profile: visitibz
# URL: https://www.instagram.com/p/CMblISGrnh5/
# Date: 2021-03-15
# Time: 13:52:29
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 10/50
# #########################################################
# Profile: sebzmusicmx
# URL: https://www.instagram.com/p/CMcKQWEBK2i/
# Date: 2021-03-15
# Time: 13:52:38
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 11/50
# #########################################################
# Profile: paolamezzadra
# URL: https://www.instagram.com/p/CMcKO2_lLe0/
# Date: 2021-03-15
# Time: 13:52:44
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 12/50
# #########################################################
# Profile: vb.fitness_
# URL: https://www.instagram.com/p/CMcKKm-Mz17/
# Date: 2021-03-15
# Time: 13:52:52
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 13/50
# #########################################################
# Profile: gizliozellikvaggcom
# URL: https://www.instagram.com/p/CMcKJcNFuni/
# Date: 2021-03-15
# Time: 13:53:01
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 14/50
# #########################################################
# Profile: techno.zombies.official
# URL: https://www.instagram.com/p/CMcJ-0fDF8d/
# Date: 2021-03-15
# Time: 13:53:09
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 15/50
# #########################################################
# Profile: presuntos_triatletas
# URL: https://www.instagram.com/p/CMcKAcnLTk5/
# Date: 2021-03-15
# Time: 13:53:14
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 16/50
# #########################################################
# Profile: badlydrawndjs
# URL: https://www.instagram.com/p/CMcJ8epA-PU/
# Date: 2021-03-15
# Time: 13:53:20
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 17/50
# #########################################################
# Profile: c4ciofernandez
# URL: https://www.instagram.com/p/CMcJ8fojxkD/
# Date: 2021-03-15
# Time: 13:53:28
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 18/50
# #########################################################
# Profile: gizliozellikvaggcom
# URL: https://www.instagram.com/p/CMcJ4M5gptN/
# Date: 2021-03-15
# Time: 13:53:37
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 19/50
# #########################################################
# Profile: jpchronic
# URL: https://www.instagram.com/p/CMcJyGTA0nV/
# Date: 2021-03-15
# Time: 13:53:48
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 20/50
# #########################################################
# Profile: privatechefibiza_
# URL: https://www.instagram.com/p/CMcJ17Hr3Kw/
# Date: 2021-03-15
# Time: 13:53:57
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 21/50
# #########################################################
# Profile: technoblinders
# URL: https://www.instagram.com/p/CMcJqfgAWPa/
# Date: 2021-03-15
# Time: 13:54:04
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 22/50
# #########################################################
# Profile: afa_azizova_services
# URL: https://www.instagram.com/p/CMcJxgshpwQ/
# Date: 2021-03-15
# Time: 13:54:11
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 23/50
# #########################################################
# Profile: sharon_polverino
# URL: https://www.instagram.com/p/CMcJwcSlFPd/
# Date: 2021-03-15
# Time: 13:54:18
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 24/50
# #########################################################
# Profile: le.verger.music
# URL: https://www.instagram.com/p/CMcJDr4ho9G/
# Date: 2021-03-15
# Time: 13:54:25
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 25/50
# #########################################################
# Profile: lordsofhouse
# URL: https://www.instagram.com/p/CMcJkYlATop/
# Date: 2021-03-15
# Time: 13:54:33
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 26/50
# #########################################################
# Profile: luciarosillomontes
# URL: https://www.instagram.com/p/CMcJtMbLgB_/
# Date: 2021-03-15
# Time: 13:54:40
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 27/50
# #########################################################
# Profile: gizliozellikvaggcom
# URL: https://www.instagram.com/p/CMcJl5XgHuv/
# Date: 2021-03-15
# Time: 13:54:47
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 28/50
# #########################################################
# Profile: missparadis_
# URL: https://www.instagram.com/p/CMcJspFMFh3/
# Date: 2021-03-15
# Time: 13:54:56
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 29/50
# #########################################################
# Profile: ibizasecretplaces
# URL: https://www.instagram.com/p/CMcJqJOKmeP/
# Date: 2021-03-15
# Time: 13:55:05
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 30/50
# #########################################################
# Profile: aboutawesomemoments
# URL: https://www.instagram.com/p/CMcJr9kAL99/
# Date: 2021-03-15
# Time: 13:55:13
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 31/50
# #########################################################
# Profile: ipizzaibiza
# URL: https://www.instagram.com/p/CMcJrrmLhTc/
# Date: 2021-03-15
# Time: 13:55:22
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 32/50
# #########################################################
# Profile: rodritomba26
# URL: https://www.instagram.com/p/CMcJonKBWqT/
# Date: 2021-03-15
# Time: 13:55:32
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 33/50
# #########################################################
# Profile: jancars_
# URL: https://www.instagram.com/p/CMcJlYvLPc_/
# Date: 2021-03-15
# Time: 13:55:40
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 34/50
# #########################################################
# Profile: promopush_uk
# URL: https://www.instagram.com/p/CMcJlXggSDz/
# Date: 2021-03-15
# Time: 13:55:49
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 35/50
# #########################################################
# Profile: louise.cameron.edlund
# URL: https://www.instagram.com/p/CMcJi9DrdqA/
# Date: 2021-03-15
# Time: 13:55:54
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 36/50
# #########################################################
# Profile: oliver_prats
# URL: https://www.instagram.com/p/CMcJgy1rCnN/
# Date: 2021-03-15
# Time: 13:55:59
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 37/50
# #########################################################
# Profile: privatechefibiza_
# URL: https://www.instagram.com/p/CMcJeAlLgic/
# Date: 2021-03-15
# Time: 13:56:04
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 38/50
# #########################################################
# Profile: morgan_dope_music
# URL: https://www.instagram.com/p/CMcJdS8nFog/
# Date: 2021-03-15
# Time: 13:56:13
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 39/50
# #########################################################
# Profile: dbycont
# URL: https://www.instagram.com/p/CMcJcYtrYJ8/
# Date: 2021-03-15
# Time: 13:56:20
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 40/50
# #########################################################
# Profile: gizliozellikvaggcom
# URL: https://www.instagram.com/p/CMcJIjJgVOM/
# Date: 2021-03-15
# Time: 13:56:27
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 41/50
# #########################################################
# Profile: alvaro_suruba
# URL: https://www.instagram.com/p/CMcJXu7h39F/
# Date: 2021-03-15
# Time: 13:56:35
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 42/50
# #########################################################
# Profile: inmobiliaria_cardona
# URL: https://www.instagram.com/p/CMcJUkirDJa/
# Date: 2021-03-15
# Time: 13:56:44
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 43/50
# #########################################################
# Profile: janainafrancischetto
# URL: https://www.instagram.com/p/CMcJGWCj2Uv/
# Date: 2021-03-15
# Time: 13:56:54
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 44/50
# #########################################################
# Profile: topb0y__
# URL: https://www.instagram.com/p/CMcJPkBlkBR/
# Date: 2021-03-15
# Time: 13:57:02
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 45/50
# #########################################################
# Profile: ib_by95
# URL: https://www.instagram.com/p/CMcJOWzskTJ/
# Date: 2021-03-15
# Time: 13:57:11
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 46/50
# #########################################################
# Profile: vinithodar
# URL: https://www.instagram.com/p/CMcJOIhjQbN/
# Date: 2021-03-15
# Time: 13:57:18
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 47/50
# #########################################################
# Profile: mnob_photo
# URL: https://www.instagram.com/p/CMcJLX8DLQi/
# Date: 2021-03-15
# Time: 13:57:24
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 48/50
# #########################################################
# Profile: privatechefibiza_
# URL: https://www.instagram.com/p/CMcJKReLkar/
# Date: 2021-03-15
# Time: 13:57:30
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 49/50
# #########################################################
# Profile: pat58_83_
# URL: https://www.instagram.com/p/CMcI616CLMn/
# Date: 2021-03-15
# Time: 13:57:40
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
# Starting Engagement: 50/50
# #########################################################
# Profile: empresasguillermo1
# URL: https://www.instagram.com/p/CMcI3AICdLB/
# Date: 2021-03-15
# Time: 13:57:51
# Engagement Recorded.
# #########################################################
# Completing Engagement.
# Engagement Complete.
# ---------------------------------------------------------
#
# Engagement Function Complete.
# Disconnecting from MAIA Database
# Closing Browser.
